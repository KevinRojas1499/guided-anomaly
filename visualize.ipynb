# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the .npz file
data = np.load('images/samples_12x128x128x3.npz')

# Assuming the array of images is stored with the key 'images'
# Replace 'images' with the actual key name if it's different
images = data['arr_0']

# Check if images array is in the expected shape
print("Shape of the images array:", images.shape)

# Visualize the first few images
num_images_to_show = 16  # You can change this number

plt.figure(figsize=(20, 20))
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(images[i])
    plt.axis('off')
plt.show()
# Out:
# Shape of the images array: (12, 128, 128, 3)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 20
#      18 for i in range(num_images_to_show):
#      19     plt.subplot(1, num_images_to_show, i + 1)
# ---> 20     plt.imshow(images[i])
#      21     plt.axis('off')
#      22 plt.show()
#
# IndexError: index 12 is out of bounds for axis 0 with size 12

# %%
images.shape
# Out:
# (12, 128, 128, 3)

# %%
data['arr_1']
# Out:
# array([540, 820, 445, 679, 525, 320, 450, 401, 194,  53, 726,  84, 743,
#        867, 648, 782])

# %%
print("Keys in the .npz file:", data.files)
# Out:
# Keys in the .npz file: ['arr_0', 'arr_1']
